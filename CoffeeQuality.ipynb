# %% [markdown]
# <a href="https://colab.research.google.com/github/steffyjohnson/COGNOS/blob/main/CoffeeQuality.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
coffee=pd.read_csv("df_coffee_qlty.csv")

# %%
coffee.head()

# %%
coffee.drop(columns=["ID","Unnamed: 0"],axis=1,inplace=True)

# %%
coffee.head()

# %%
coffee.dtypes

# %%
coffee.isnull().sum()

# %%
coffee.dropna(inplace=True)

# %%
correlation=coffee.corr()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

plt.figure(figsize=(15,6))
sns.heatmap(correlation,cmap="Greens",annot=True,)
plt.title("Heatmap Coffee Data")
plt.show()
